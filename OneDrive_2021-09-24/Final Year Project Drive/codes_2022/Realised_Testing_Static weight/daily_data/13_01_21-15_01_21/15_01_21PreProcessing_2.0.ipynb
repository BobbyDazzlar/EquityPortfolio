# %%
import pandas as pd
import numpy as np
from datetime import date,timedelta

# %%
from yahoofinance import HistoricalPrices as get_history
#ensure yahoofinance package is installed  "pip install yahoofinance"
import yfinance as yf

# %% [markdown]
# # Change the dates here carefully

# %%
start_date = date(2021,1,13)
#date in Year, Month, Day
end_date = date(2021,1,16)

# %%
#nifty_50_stocks_list=pd.read_csv('ind_nifty50list2022.csv')
#use the csv file from nifty website
nifty_50_stocks = ["ASIANPAINT","BAJFINANCE","BAJAJFINSV","BRITANNIA",'DIVISLAB','GRASIM','HCLTECH','HDFCBANK',
                   'HINDALCO','HINDUNILVR','ICICIBANK','INFY','JSWSTEEL','LT','NESTLEIND','POWERGRID','RELIANCE','TCS','TATACONSUM','TATASTEEL',
                   'TECHM','TITAN','ULTRACEMCO','WIPRO'] 
#Choose the stock symbols

# %% [markdown]
# ## Data collection
# ###

# %%
k=0 
for i in nifty_50_stocks :
    print(str(k+1)+": stock_name:\t", i)
    k+=1
    x = yf.download( i+'.NS',start=start_date,end=end_date) #yahoofinance function to get the stock data
    
    x.to_csv('{}.csv'.format(i))
# Out:
# 1: stock_name:	 ASIANPAINT
# [*********************100%***********************]  1 of 1 completed
# 2: stock_name:	 BAJFINANCE
# [*********************100%***********************]  1 of 1 completed
# 3: stock_name:	 BAJAJFINSV
# [*********************100%***********************]  1 of 1 completed
# 4: stock_name:	 BRITANNIA
# [*********************100%***********************]  1 of 1 completed
# 5: stock_name:	 DIVISLAB
# [*********************100%***********************]  1 of 1 completed
# 6: stock_name:	 GRASIM
# [*********************100%***********************]  1 of 1 completed
# 7: stock_name:	 HCLTECH
# [*********************100%***********************]  1 of 1 completed
# 8: stock_name:	 HDFCBANK
# [*********************100%***********************]  1 of 1 completed
# 9: stock_name:	 HINDALCO
# [*********************100%***********************]  1 of 1 completed
# 10: stock_name:	 HINDUNILVR
# [*********************100%***********************]  1 of 1 completed
# 11: stock_name:	 ICICIBANK
# [*********************100%***********************]  1 of 1 completed
# 12: stock_name:	 INFY
# [*********************100%***********************]  1 of 1 completed
# 13: stock_name:	 JSWSTEEL
# [*********************100%***********************]  1 of 1 completed
# 14: stock_name:	 LT
# [*********************100%***********************]  1 of 1 completed
# 15: stock_name:	 NESTLEIND
# [*********************100%***********************]  1 of 1 completed
# 16: stock_name:	 POWERGRID
# [*********************100%***********************]  1 of 1 completed
# 17: stock_name:	 RELIANCE
# [*********************100%***********************]  1 of 1 completed
# 18: stock_name:	 TCS
# [*********************100%***********************]  1 of 1 completed
# 19: stock_name:	 TATACONSUM
# [*********************100%***********************]  1 of 1 completed
# 20: stock_name:	 TATASTEEL
# [*********************100%***********************]  1 of 1 completed
# 21: stock_name:	 TECHM
# [*********************100%***********************]  1 of 1 completed
# 22: stock_name:	 TITAN
# [*********************100%***********************]  1 of 1 completed
# 23: stock_name:	 ULTRACEMCO
# [*********************100%***********************]  1 of 1 completed
# 24: stock_name:	 WIPRO
# [*********************100%***********************]  1 of 1 completed

# %%
nifty50=pd.DataFrame()
nifty50
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in nifty_50_stocks:
    x = pd.read_csv('{}.csv'.format(i), usecols=["Adj Close","Date"],index_col="Date")
    print(x)
    nifty50 = pd.concat([nifty50,x],axis = 1)
                                                       #getting each stock data one by one and concatanating it into the 'allData' frame
# Out:
#               Adj Close
# Date
# 2021-01-13  2687.208252
# 2021-01-14  2647.651123
# 2021-01-15  2575.096191
#               Adj Close
# Date
# 2021-01-13  4894.990234
# 2021-01-14  4869.481445
# 2021-01-15  4875.721680
#               Adj Close
# Date
# 2021-01-13  8791.518555
# 2021-01-14  8745.229492
# 2021-01-15  8634.005859
#               Adj Close
# Date
# 2021-01-13  3549.023438
# 2021-01-14  3592.441162
# 2021-01-15  3537.164551
#               Adj Close
# Date
# 2021-01-13  3704.215332
# 2021-01-14  3709.493896
# 2021-01-15  3629.920166
#               Adj Close
# Date
# 2021-01-13  1030.598755
# 2021-01-14  1017.533691
# 2021-01-15  1030.299683
#               Adj Close
# Date
# 2021-01-13  1017.157288
# 2021-01-14   989.945129
# 2021-01-15   953.437561
#               Adj Close
# Date
# 2021-01-13  1464.312500
# 2021-01-14  1462.420654
# 2021-01-15  1460.329712
#              Adj Close
# Date
# 2021-01-13  260.845459
# 2021-01-14  259.604034
# 2021-01-15  251.609360
#               Adj Close
# Date
# 2021-01-13  2340.922119
# 2021-01-14  2366.775146
# 2021-01-15  2320.002930
#              Adj Close
# Date
# 2021-01-13  554.875305
# 2021-01-14  551.684631
# 2021-01-15  541.414734
#               Adj Close
# Date
# 2021-01-13  1360.285645
# 2021-01-14  1343.958130
# 2021-01-15  1318.902954
#              Adj Close
# Date
# 2021-01-13  395.192810
# 2021-01-14  388.768890
# 2021-01-15  386.611267
#               Adj Close
# Date
# 2021-01-13  1337.362427
# 2021-01-14  1361.192749
# 2021-01-15  1338.994019
#                Adj Close
# Date
# 2021-01-13  17816.359375
# 2021-01-14  17928.382812
# 2021-01-15  17633.148438
#              Adj Close
# Date
# 2021-01-13  142.234024
# 2021-01-14  142.303421
# 2021-01-15  140.846375
#               Adj Close
# Date
# 2021-01-13  1932.583130
# 2021-01-14  1954.313110
# 2021-01-15  1931.237305
#               Adj Close
# Date
# 2021-01-13  3119.292969
# 2021-01-14  3215.999268
# 2021-01-15  3198.834961
#              Adj Close
# Date
# 2021-01-13  616.825134
# 2021-01-14  610.461975
# 2021-01-15  598.928833
#              Adj Close
# Date
# 2021-01-13  693.627747
# 2021-01-14  690.888977
# 2021-01-15  690.448914
#               Adj Close
# Date
# 2021-01-13  1031.414673
# 2021-01-14  1014.974060
# 2021-01-15   971.293396
#               Adj Close
# Date
# 2021-01-13  1502.196411
# 2021-01-14  1486.384277
# 2021-01-15  1473.714722
#               Adj Close
# Date
# 2021-01-13  5623.309082
# 2021-01-14  5555.241211
# 2021-01-15  5425.772949
#              Adj Close
# Date
# 2021-01-13  457.225983
# 2021-01-14  452.593964
# 2021-01-15  436.854980

# %%
nifty50.columns=nifty_50_stocks

# %%
nifty50
# Out:
#              ASIANPAINT   BAJFINANCE   BAJAJFINSV    BRITANNIA     DIVISLAB  \
# Date
# 2021-01-13  2687.208252  4894.990234  8791.518555  3549.023438  3704.215332
# 2021-01-14  2647.651123  4869.481445  8745.229492  3592.441162  3709.493896
# 2021-01-15  2575.096191  4875.721680  8634.005859  3537.164551  3629.920166
#
#                  GRASIM      HCLTECH     HDFCBANK    HINDALCO   HINDUNILVR  \
# Date
# 2021-01-13  1030.598755  1017.157288  1464.312500  260.845459  2340.922119
# 2021-01-14  1017.533691   989.945129  1462.420654  259.604034  2366.775146
# 2021-01-15  1030.299683   953.437561  1460.329712  251.609360  2320.002930
#
#             ...     NESTLEIND   POWERGRID     RELIANCE          TCS  \
# Date        ...
# 2021-01-13  ...  17816.359375  142.234024  1932.583130  3119.292969
# 2021-01-14  ...  17928.382812  142.303421  1954.313110  3215.999268
# 2021-01-15  ...  17633.148438  140.846375  1931.237305  3198.834961
#
#             TATACONSUM   TATASTEEL        TECHM        TITAN   ULTRACEMCO  \
# Date
# 2021-01-13  616.825134  693.627747  1031.414673  1502.196411  5623.309082
# 2021-01-14  610.461975  690.888977  1014.974060  1486.384277  5555.241211
# 2021-01-15  598.928833  690.448914   971.293396  1473.714722  5425.772949
#
#                  WIPRO
# Date
# 2021-01-13  457.225983
# 2021-01-14  452.593964
# 2021-01-15  436.854980
#
# [3 rows x 24 columns]

# %%
nifty50.to_csv(str(end_date - timedelta(days=1))+'.csv')  #saving the data without preprocessing
