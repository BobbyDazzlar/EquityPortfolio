# %%
4.57606371261345,9.67698598407907,2.8816471398668,3.76280675093989,6.10005496604961,1.14708159257701,1.63996379334881,3.36411165704113,2.00796787062891,9.13229658964017,1.37274941345458,2.38654278474067,6.25880838891221,2.14733058728827,9.76228755822564,2.01419193025687,7.83900398874845,7.72870344184099,2.27786673057532,3.33226384976688,1.03163727917332,7.21709695950646,0.606271511043036,1.73626551968245
# Out:
# (4.57606371261345,
#  9.67698598407907,
#  2.8816471398668,
#  3.76280675093989,
#  6.10005496604961,
#  1.14708159257701,
#  1.63996379334881,
#  3.36411165704113,
#  2.00796787062891,
#  9.13229658964017,
#  1.37274941345458,
#  2.38654278474067,
#  6.25880838891221,
#  2.14733058728827,
#  9.76228755822564,
#  2.01419193025687,
#  7.83900398874845,
#  7.72870344184099,
#  2.27786673057532,
#  3.33226384976688,
#  1.03163727917332,
#  7.21709695950646,
#  0.606271511043036,
#  1.73626551968245)

# %%
import pandas as pd
import numpy as np
import random
import math

# %%
def BALANCE(weights):
  #Making sure the total sum of the weights eual to 1
  weights = [w/sum(weights) for w in weights] 
  # Making sure all weights represent proportions that add up to 1
  return weights

# %%
def ratio(a,b,c):                       
  #function to calculate ratio i.e. "(returns-(risk_free_rate))/deviation"
  #calculating sharpe ratio
  return (a-c)/b

# %%
# def number_of_years(y):#calculates the number of years of the dataset
#   p=y.index[0]         #date of first row in the dataset (datetime format)
#   q=y.index[len(y)-1]  #date of last row in the dataset  (datetime format)
#   return ((q-p).days+1)/365

# %%
df=pd.read_csv("2021-01-11_B.csv",parse_dates=['Date'],index_col='Date')  #Importing Dataset
#df = df.loc["2016-01-01" :"2020-12-31" ]   #Since 2016-01-01, 5y(1234rows till 2020-12-31)
tdf=df.copy()                  #deep copy
df.reset_index(drop=True, inplace=True)
col=list(df.columns)
tdf.shape
# Out:
# (3, 24)

# %%
end=tdf.index[2].date()

# %%
trading_days=250#len(df)/number_of_years(tdf)

# %%
returnsh=df                
#Here, returnsh would mean return considered for sharpe ratio
returnsh.fillna(0,inplace=True)

# %%
returnsh=returnsh
returnsh
# Out:
#    ASIANPAINT  BAJFINANCE  BAJAJFINSV  BRITANNIA  DIVISLAB    GRASIM  \
# 0   -0.009205    0.001541    0.018801  -0.021900 -0.026343  0.001216
# 1    0.003317   -0.010955    0.014761  -0.019575  0.006388  0.001977
# 2   -0.004597   -0.025801   -0.023593  -0.017457 -0.020105  0.002278
#
#     HCLTECH  HDFCBANK  HINDALCO  HINDUNILVR  ...  NESTLEIND  POWERGRID  \
# 0 -0.061550 -0.015604  0.036623   -0.038870  ...  -0.036338  -0.079339
# 1 -0.017223 -0.004553 -0.027716   -0.012752  ...  -0.006980  -0.052559
# 2  0.001319 -0.003314 -0.017633   -0.011579  ...  -0.009029  -0.076941
#
#    RELIANCE       TCS  TATACONSUM  TATASTEEL     TECHM     TITAN  ULTRACEMCO  \
# 0 -0.008060 -0.026105   -0.020194   0.020172 -0.046055 -0.019963   -0.018861
# 1  0.004953 -0.002679   -0.001256  -0.040522  0.005733 -0.001942    0.026868
# 2 -0.024569 -0.028925    0.020188  -0.044349 -0.021673  0.000101    0.008359
#
#       WIPRO
# 0 -0.017155
# 1  0.051625
# 2  0.020810
#
# [3 rows x 24 columns]

# %%
returnso = returnsh.copy()  # this cell considers only NEGATIVE returns so as to calculate sortino ratio
for cols in returnso.columns.tolist():
  for i in range(1, len(df)):
    if returnso[cols][i] > 0:
      returnso[cols][i] = 0

# %%
returnso
# Out:
#    ASIANPAINT  BAJFINANCE  BAJAJFINSV  BRITANNIA  DIVISLAB    GRASIM  \
# 0   -0.009205    0.001541    0.018801  -0.021900 -0.026343  0.001216
# 1    0.000000   -0.010955    0.000000  -0.019575  0.000000  0.000000
# 2   -0.004597   -0.025801   -0.023593  -0.017457 -0.020105  0.000000
#
#     HCLTECH  HDFCBANK  HINDALCO  HINDUNILVR  ...  NESTLEIND  POWERGRID  \
# 0 -0.061550 -0.015604  0.036623   -0.038870  ...  -0.036338  -0.079339
# 1 -0.017223 -0.004553 -0.027716   -0.012752  ...  -0.006980  -0.052559
# 2  0.000000 -0.003314 -0.017633   -0.011579  ...  -0.009029  -0.076941
#
#    RELIANCE       TCS  TATACONSUM  TATASTEEL     TECHM     TITAN  ULTRACEMCO  \
# 0 -0.008060 -0.026105   -0.020194   0.020172 -0.046055 -0.019963   -0.018861
# 1  0.000000 -0.002679   -0.001256  -0.040522  0.000000 -0.001942    0.000000
# 2 -0.024569 -0.028925    0.000000  -0.044349 -0.021673  0.000000    0.000000
#
#       WIPRO
# 0 -0.017155
# 1  0.000000
# 2  0.000000
#
# [3 rows x 24 columns]

# %%
covmatsh=returnsh.cov()*trading_days     
#Annualised covariance matrix calculated wrt returnsh i.e. used to calculate sharpe ratio
covmatso = returnso.cov() * trading_days

# %%
covmatsh
# Out:
#             ASIANPAINT  BAJFINANCE  BAJAJFINSV  BRITANNIA  DIVISLAB    GRASIM  \
# ASIANPAINT    0.010028   -0.006872    0.002402   0.001367  0.027012  0.000501
# BAJFINANCE   -0.006872    0.046838    0.074124  -0.007583 -0.007761 -0.001791
# BAJAJFINSV    0.002402    0.074124    0.136855  -0.011626  0.025807 -0.002484
# BRITANNIA     0.001367   -0.007583   -0.011626   0.001235  0.001987  0.000297
# DIVISLAB      0.027012   -0.007761    0.025807   0.001987  0.075505  0.000981
# GRASIM        0.000501   -0.001791   -0.002484   0.000297  0.000981  0.000075
# HCLTECH       0.029081   -0.106170   -0.148144   0.017570  0.056328  0.004418
# HDFCBANK      0.007717   -0.020522   -0.025551   0.003455  0.016899  0.000909
# HINDALCO     -0.047308    0.089071    0.090556  -0.015388 -0.112978 -0.004313
# HINDUNILVR    0.018479   -0.045414   -0.054477   0.007686  0.041418  0.002050
# ICICIBANK     0.006672   -0.032558   -0.048737   0.005325  0.010830  0.001295
# INFY          0.036959   -0.083769   -0.096255   0.014259  0.084644  0.003857
# JSWSTEEL     -0.016314    0.020159    0.012241  -0.003641 -0.041655 -0.001124
# LT            0.013128    0.052984    0.114623  -0.007988  0.051179 -0.001474
# NESTLEIND     0.021236   -0.045129   -0.049906   0.007719  0.049400  0.002113
# POWERGRID     0.022474   -0.001592    0.030221   0.000886  0.064062  0.000649
# RELIANCE      0.013356    0.030294    0.074148  -0.004402  0.046042 -0.000688
# TCS           0.020336    0.007251    0.042979  -0.000569  0.060186  0.000289
# TATACONSUM    0.010560   -0.069130   -0.108790   0.011204  0.012652  0.002655
# TATASTEEL    -0.042790    0.107472    0.130303  -0.018163 -0.095322 -0.004825
# TECHM         0.040739   -0.037786   -0.007987   0.007112  0.107219  0.002376
# TITAN         0.012580   -0.033503   -0.041738   0.005641  0.027537  0.001484
# ULTRACEMCO    0.035188   -0.043368   -0.026200   0.007836  0.089871  0.002421
# WIPRO         0.053336   -0.059999   -0.029394   0.010972  0.137687  0.003473
#
#              HCLTECH  HDFCBANK  HINDALCO  HINDUNILVR  ...  NESTLEIND  \
# ASIANPAINT  0.029081  0.007717 -0.047308    0.018479  ...   0.021236
# BAJFINANCE -0.106170 -0.020522  0.089071   -0.045414  ...  -0.045129
# BAJAJFINSV -0.148144 -0.025551  0.090556   -0.054477  ...  -0.049906
# BRITANNIA   0.017570  0.003455 -0.015388    0.007686  ...   0.007719
# DIVISLAB    0.056328  0.016899 -0.112978    0.041418  ...   0.049400
# GRASIM      0.004418  0.000909 -0.004313    0.002050  ...   0.002113
# HCLTECH     0.260882  0.053565 -0.253166    0.120633  ...   0.124178
# HDFCBANK    0.053565  0.011447 -0.056891    0.026063  ...   0.027399
# HINDALCO   -0.253166 -0.056891  0.299365   -0.131217  ...  -0.141301
# HINDUNILVR  0.120633  0.026063 -0.131217    0.059512  ...   0.062902
# ICICIBANK   0.076639  0.015254 -0.069109    0.034051  ...   0.034441
# INFY        0.226818  0.049574 -0.252949    0.113538  ...   0.120684
# JSWSTEEL   -0.065694 -0.015802  0.089041   -0.037044  ...  -0.041066
# LT         -0.088810 -0.012310  0.021412   -0.023992  ...  -0.017184
# NESTLEIND   0.124178  0.027399 -0.141301    0.062902  ...   0.067163
# POWERGRID   0.036907  0.012301 -0.087457    0.030679  ...   0.037570
# RELIANCE   -0.042021 -0.003987 -0.009963   -0.006055  ...  -0.000348
# TCS         0.015604  0.007988 -0.067450    0.021004  ...   0.027688
# TATACONSUM  0.157328  0.030508 -0.133050    0.067576  ...   0.067285
# TATASTEEL  -0.284071 -0.061188  0.306959   -0.139603  ...  -0.147335
# TECHM       0.138344  0.034919 -0.205463    0.082742  ...   0.093434
# TITAN       0.087418  0.018678 -0.092807    0.042525  ...   0.044699
# ULTRACEMCO  0.141462  0.034041 -0.191897    0.079810  ...   0.088491
# WIPRO       0.202677  0.049523 -0.283154    0.116512  ...   0.129967
#
#             POWERGRID  RELIANCE       TCS  TATACONSUM  TATASTEEL     TECHM  \
# ASIANPAINT   0.022474  0.013356  0.020336    0.010560  -0.042790  0.040739
# BAJFINANCE  -0.001592  0.030294  0.007251   -0.069130   0.107472 -0.037786
# BAJAJFINSV   0.030221  0.074148  0.042979   -0.108790   0.130303 -0.007987
# BRITANNIA    0.000886 -0.004402 -0.000569    0.011204  -0.018163  0.007112
# DIVISLAB     0.064062  0.046042  0.060186    0.012652  -0.095322  0.107219
# GRASIM       0.000649 -0.000688  0.000289    0.002655  -0.004825  0.002376
# HCLTECH      0.036907 -0.042021  0.015604    0.157328  -0.284071  0.138344
# HDFCBANK     0.012301 -0.003987  0.007988    0.030508  -0.061188  0.034919
# HINDALCO    -0.087457 -0.009963 -0.067450   -0.133050   0.306959 -0.205463
# HINDUNILVR   0.030679 -0.006055  0.021004    0.067576  -0.139603  0.082742
# ICICIBANK    0.005779 -0.017320 -0.000545    0.048143  -0.080384  0.033659
# INFY         0.063676 -0.005497  0.045562    0.124781  -0.266118  0.163838
# JSWSTEEL    -0.033620 -0.013321 -0.028570   -0.030372   0.086272 -0.068382
# LT           0.049739  0.075521  0.057795   -0.077235   0.058955  0.038816
# NESTLEIND    0.037570 -0.000348  0.027688    0.067285  -0.147335  0.093434
# POWERGRID    0.054894  0.042862  0.052522    0.003380  -0.070285  0.088068
# RELIANCE     0.042862  0.054724  0.046924   -0.043889   0.016183  0.045019
# TCS          0.052522  0.046924  0.051897   -0.009711  -0.047477  0.077655
# TATACONSUM   0.003380 -0.043889 -0.009711    0.102053  -0.159875  0.057399
# TATASTEEL   -0.070285  0.016183 -0.047477   -0.159875   0.327557 -0.192143
# TECHM        0.088068  0.045019  0.077655    0.057399  -0.192143  0.167816
# TITAN        0.020037 -0.006544  0.012998    0.049804  -0.099836  0.056934
# ULTRACEMCO   0.072550  0.028836  0.061677    0.065344  -0.185868  0.147463
# WIPRO        0.111849  0.049080  0.096372    0.090617  -0.271089  0.222173
#
#                TITAN  ULTRACEMCO     WIPRO
# ASIANPAINT  0.012580    0.035188  0.053336
# BAJFINANCE -0.033503   -0.043368 -0.059999
# BAJAJFINSV -0.041738   -0.026200 -0.029394
# BRITANNIA   0.005641    0.007836  0.010972
# DIVISLAB    0.027537    0.089871  0.137687
# GRASIM      0.001484    0.002421  0.003473
# HCLTECH     0.087418    0.141462  0.202677
# HDFCBANK    0.018678    0.034041  0.049523
# HINDALCO   -0.092807   -0.191897 -0.283154
# HINDUNILVR  0.042525    0.079810  0.116512
# ICICIBANK   0.024899    0.036202  0.051062
# INFY        0.080881    0.156400  0.229106
# JSWSTEEL   -0.025770   -0.061351 -0.091771
# LT         -0.020138    0.017739  0.035328
# NESTLEIND   0.044699    0.088491  0.129967
# POWERGRID   0.020037    0.072550  0.111849
# RELIANCE   -0.006544    0.028836  0.049080
# TCS         0.012998    0.061677  0.096372
# TATACONSUM  0.049804    0.065344  0.090617
# TATASTEEL  -0.099836   -0.185868 -0.271089
# TECHM       0.056934    0.147463  0.222173
# TITAN       0.030477    0.055515  0.080758
# ULTRACEMCO  0.055515    0.132274  0.197873
# WIPRO       0.080758    0.197873  0.296734
#
# [24 rows x 24 columns]

# %%
risk_free_rate = 0.0358 #initializing risk free rate that will be used in calculating both the ratios (absolute value)
#referred from url: https://www.rbi.org.in/Scripts/BS_NSDPDisplay.aspx?param=4&Id=24292
#In the above url, the 364 (1 year) day treasury bill is 3.58% , when taken absolute value => 0.0358
# (improved)

# %%
df
stocks=df.shape[1]
stocks
# Out:
# 24

# %% [markdown]
# # Sharpe

# %%
global_warr_sortino=[]
global_war_sharpe=[]
sharpe_portfolio_return=[]
sharpe_portfolio_risk=[]
sharpe_portfolio_shratio=[]
sharpe_portfolio_stockWeights=[]

# %%
fitness=0
#for each iteration

weights=(np.array(BALANCE([4.57606371261345,9.67698598407907,2.8816471398668,3.76280675093989,6.10005496604961,1.14708159257701,1.63996379334881,3.36411165704113,2.00796787062891,9.13229658964017,1.37274941345458,2.38654278474067,6.25880838891221,2.14733058728827,9.76228755822564,2.01419193025687,7.83900398874845,7.72870344184099,2.27786673057532,3.33226384976688,1.03163727917332,7.21709695950646,0.606271511043036,1.73626551968245
])))

#calculating annulaised portfolio return
returns_temp = np.sum(returnsh.mean()*weights)*trading_days 

#calculating portfolio varience wrt calculating sharpe ratio
varsh=np.dot(weights.T,np.dot(covmatsh,weights))   

#portfolio risk
volatility_temp = np.sqrt(varsh)      

#Calculating fitness value(ie sharpe ratio)
fitness = ratio(returns_temp,volatility_temp,risk_free_rate)

#Initializing the intial fitness value as the best fitness value(sharpe_pbest)


sharpe_portfolio_return.append(returns_temp)
sharpe_portfolio_risk.append(volatility_temp)
sharpe_portfolio_shratio.append(fitness)
sharpe_portfolio_stockWeights.append(weights)

# %%
sharpe_portfolio = {'Returns' : sharpe_portfolio_return, 'Standard Deviation' : sharpe_portfolio_risk,  'Sharpe Ratio' : sharpe_portfolio_shratio}  

for counter,symbol in enumerate(df.columns):
  sharpe_portfolio[symbol + " Weight"] = [Weight[counter] for Weight in sharpe_portfolio_stockWeights]
sharpe_pc = pd.DataFrame(sharpe_portfolio)
sharpe_optimal=sharpe_pc.iloc[sharpe_pc['Sharpe Ratio'].idxmax()]
sharpe_optimal=pd.DataFrame(sharpe_optimal)
sharpe_optimal.to_csv(str(end)+"Sharpe_MVO_B.csv")

sharpe_pc
# Out:
#     Returns  Standard Deviation  Sharpe Ratio  ASIANPAINT Weight  \
# 0 -3.549796            0.098631    -36.353468           0.045761
#
#    BAJFINANCE Weight  BAJAJFINSV Weight  BRITANNIA Weight  DIVISLAB Weight  \
# 0            0.09677           0.028816          0.037628         0.061001
#
#    GRASIM Weight  HCLTECH Weight  ...  NESTLEIND Weight  POWERGRID Weight  \
# 0       0.011471          0.0164  ...          0.097623          0.020142
#
#    RELIANCE Weight  TCS Weight  TATACONSUM Weight  TATASTEEL Weight  \
# 0          0.07839    0.077287           0.022779          0.033323
#
#    TECHM Weight  TITAN Weight  ULTRACEMCO Weight  WIPRO Weight
# 0      0.010316      0.072171           0.006063      0.017363
#
# [1 rows x 27 columns]

# %%
sharpe_pc.shape
# Out:
# (1, 27)

# %% [markdown]
# # Sortino

# %%
global_warr_sortino=[]
sortino_portfolio_return=[]
sortino_portfolio_risk=[]
sortino_portfolio_soratio=[]
sortino_portfolio_stockWeights=[]

# %%
fitness=0
#for each iteration


#Making sure that the total amount of pheromone equals 1 
weights=np.array(BALANCE([4.57606371261345,9.67698598407907,2.8816471398668,3.76280675093989,6.10005496604961,1.14708159257701,1.63996379334881,3.36411165704113,2.00796787062891,9.13229658964017,1.37274941345458,2.38654278474067,6.25880838891221,2.14733058728827,9.76228755822564,2.01419193025687,7.83900398874845,7.72870344184099,2.27786673057532,3.33226384976688,1.03163727917332,7.21709695950646,0.606271511043036,1.73626551968245
]))

#calculating annulaised portfolio return
returns_temp = np.sum(returnsh.mean()*weights)*trading_days 

#calculating portfolio varience wrt calculating sharpe ratio
varso=np.dot(weights.T,np.dot(covmatso,weights))   

#portfolio risk
volatility_temp = np.sqrt(varso)      

#Calculating fitness value(ie sortino ratio)
fitness = ratio(returns_temp,volatility_temp,risk_free_rate)

#Initializing the intial fitness value as the best fitness value(sortino_pbest)

sortino_portfolio_return.append(returns_temp)
sortino_portfolio_risk.append(volatility_temp)
sortino_portfolio_soratio.append(fitness)
sortino_portfolio_stockWeights.append(weights)

# %%
sortino_portfolio = {'Returns' : sortino_portfolio_return, 'Standard Deviation' : sortino_portfolio_risk,  'Sortino Ratio' : sortino_portfolio_soratio}  

for counter,symbol in enumerate(df.columns):
  sortino_portfolio[symbol + " Weight"] = [Weight[counter] for Weight in sortino_portfolio_stockWeights]
sortino_pc = pd.DataFrame(sortino_portfolio)
sortino_optimal=sortino_pc.iloc[sortino_pc['Sortino Ratio'].idxmax()]
sortino_optimal=pd.DataFrame(sortino_optimal)
sortino_optimal.to_csv(str(end)+"Sortino_MVO_B.csv")
sortino_pc
# Out:
#     Returns  Standard Deviation  Sortino Ratio  ASIANPAINT Weight  \
# 0 -3.549796            0.076989     -46.572759           0.045761
#
#    BAJFINANCE Weight  BAJAJFINSV Weight  BRITANNIA Weight  DIVISLAB Weight  \
# 0            0.09677           0.028816          0.037628         0.061001
#
#    GRASIM Weight  HCLTECH Weight  ...  NESTLEIND Weight  POWERGRID Weight  \
# 0       0.011471          0.0164  ...          0.097623          0.020142
#
#    RELIANCE Weight  TCS Weight  TATACONSUM Weight  TATASTEEL Weight  \
# 0          0.07839    0.077287           0.022779          0.033323
#
#    TECHM Weight  TITAN Weight  ULTRACEMCO Weight  WIPRO Weight
# 0      0.010316      0.072171           0.006063      0.017363
#
# [1 rows x 27 columns]

# %%
#tables in word doc also(final table)
