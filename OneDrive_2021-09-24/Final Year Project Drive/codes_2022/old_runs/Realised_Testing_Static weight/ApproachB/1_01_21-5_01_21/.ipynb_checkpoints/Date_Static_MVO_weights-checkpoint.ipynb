# %%
4.57606371261345,9.67698598407907,2.8816471398668,3.76280675093989,6.10005496604961,1.14708159257701,1.63996379334881,3.36411165704113,2.00796787062891,9.13229658964017,1.37274941345458,2.38654278474067,6.25880838891221,2.14733058728827,9.76228755822564,2.01419193025687,7.83900398874845,7.72870344184099,2.27786673057532,3.33226384976688,1.03163727917332,7.21709695950646,0.606271511043036,1.73626551968245
# Out:
# (4.57606371261345,
#  9.67698598407907,
#  2.8816471398668,
#  3.76280675093989,
#  6.10005496604961,
#  1.14708159257701,
#  1.63996379334881,
#  3.36411165704113,
#  2.00796787062891,
#  9.13229658964017,
#  1.37274941345458,
#  2.38654278474067,
#  6.25880838891221,
#  2.14733058728827,
#  9.76228755822564,
#  2.01419193025687,
#  7.83900398874845,
#  7.72870344184099,
#  2.27786673057532,
#  3.33226384976688,
#  1.03163727917332,
#  7.21709695950646,
#  0.606271511043036,
#  1.73626551968245)

# %%
import pandas as pd
import numpy as np
import random
import math

# %%
def BALANCE(weights):
  #Making sure the total sum of the weights eual to 1
  weights = [w/sum(weights) for w in weights] 
  # Making sure all weights represent proportions that add up to 1
  return weights

# %%
def ratio(a,b,c):                       
  #function to calculate ratio i.e. "(returns-(risk_free_rate))/deviation"
  #calculating sharpe ratio
  return (a-c)/b

# %%
# def number_of_years(y):#calculates the number of years of the dataset
#   p=y.index[0]         #date of first row in the dataset (datetime format)
#   q=y.index[len(y)-1]  #date of last row in the dataset  (datetime format)
#   return ((q-p).days+1)/365

# %%
df=pd.read_csv("2021-01-01_B.csv",parse_dates=['Date'],index_col='Date')  #Importing Dataset
#df = df.loc["2016-01-01" :"2020-12-31" ]   #Since 2016-01-01, 5y(1234rows till 2020-12-31)
tdf=df.copy()                  #deep copy
df.reset_index(drop=True, inplace=True)
col=list(df.columns)
tdf.shape
# Out:
# (3, 24)

# %%
end=tdf.index[2].date()

# %%
trading_days=250#len(df)/number_of_years(tdf)

# %%
returnsh=df                
#Here, returnsh would mean return considered for sharpe ratio
returnsh.fillna(0,inplace=True)

# %%
returnsh=returnsh
returnsh
# Out:
#    ASIANPAINT  BAJFINANCE  BAJAJFINSV  BRITANNIA  DIVISLAB    GRASIM  \
# 0    0.008805    0.024045   -0.004497  -0.024911 -0.001534  0.022843
# 1    0.004841   -0.009061   -0.005007  -0.021095  0.010355 -0.015344
# 2   -0.000138   -0.007263   -0.006909  -0.021892 -0.001475  0.006939
#
#     HCLTECH  HDFCBANK  HINDALCO  HINDUNILVR  ...  NESTLEIND  POWERGRID  \
# 0 -0.033964 -0.009426 -0.002669   -0.006394  ...  -0.012351  -0.073927
# 1 -0.029454 -0.003407  0.010564   -0.013495  ...  -0.005193  -0.078057
# 2 -0.028045 -0.014646 -0.009571   -0.016481  ...  -0.007983  -0.072453
#
#    RELIANCE       TCS  TATACONSUM  TATASTEEL     TECHM     TITAN  ULTRACEMCO  \
# 0 -0.003082 -0.021000   -0.013151  -0.010299 -0.022574  0.000571    0.033294
# 1 -0.007307 -0.025237   -0.018326  -0.010979 -0.044338  0.009296   -0.020754
# 2 -0.003457  0.003989    0.008489  -0.024770 -0.033819 -0.004628   -0.009741
#
#       WIPRO
# 0 -0.005417
# 1  0.009331
# 2  0.004025
#
# [3 rows x 24 columns]

# %%
returnso = returnsh.copy()  # this cell considers only NEGATIVE returns so as to calculate sortino ratio
for cols in returnso.columns.tolist():
  for i in range(1, len(df)):
    if returnso[cols][i] > 0:
      returnso[cols][i] = 0

# %%
returnso
# Out:
#    ASIANPAINT  BAJFINANCE  BAJAJFINSV  BRITANNIA  DIVISLAB    GRASIM  \
# 0    0.008805    0.024045   -0.004497  -0.024911 -0.001534  0.022843
# 1    0.000000   -0.009061   -0.005007  -0.021095  0.000000 -0.015344
# 2   -0.000138   -0.007263   -0.006909  -0.021892 -0.001475  0.000000
#
#     HCLTECH  HDFCBANK  HINDALCO  HINDUNILVR  ...  NESTLEIND  POWERGRID  \
# 0 -0.033964 -0.009426 -0.002669   -0.006394  ...  -0.012351  -0.073927
# 1 -0.029454 -0.003407  0.000000   -0.013495  ...  -0.005193  -0.078057
# 2 -0.028045 -0.014646 -0.009571   -0.016481  ...  -0.007983  -0.072453
#
#    RELIANCE       TCS  TATACONSUM  TATASTEEL     TECHM     TITAN  ULTRACEMCO  \
# 0 -0.003082 -0.021000   -0.013151  -0.010299 -0.022574  0.000571    0.033294
# 1 -0.007307 -0.025237   -0.018326  -0.010979 -0.044338  0.000000   -0.020754
# 2 -0.003457  0.000000    0.000000  -0.024770 -0.033819 -0.004628   -0.009741
#
#       WIPRO
# 0 -0.005417
# 1  0.000000
# 2  0.000000
#
# [3 rows x 24 columns]

# %%
covmatsh=returnsh.cov()*trading_days     
#Annualised covariance matrix calculated wrt returnsh i.e. used to calculate sharpe ratio
covmatso = returnso.cov() * trading_days

# %%
covmatsh
# Out:
#             ASIANPAINT  BAJFINANCE  BAJAJFINSV  BRITANNIA  DIVISLAB    GRASIM  \
# ASIANPAINT    0.005020    0.016761    0.001378  -0.001590  0.000469  0.007611
# BAJFINANCE    0.016761    0.086642    0.003708  -0.009261 -0.017362  0.075092
# BAJAJFINSV    0.001378    0.003708    0.000404  -0.000321  0.000679  0.000644
# BRITANNIA    -0.001590   -0.009261   -0.000321   0.001013  0.002290 -0.008812
# DIVISLAB      0.000469   -0.017362    0.000679   0.002290  0.011721 -0.029939
# GRASIM        0.007611    0.075092    0.000644  -0.008812 -0.029939  0.091988
# HCLTECH      -0.003243   -0.013837   -0.000803   0.001415  0.001554 -0.009791
# HDFCBANK      0.003282   -0.002335    0.001287   0.000674  0.008509 -0.016553
# HINDALCO      0.004563   -0.010759    0.002008   0.001904  0.016464 -0.035177
# HINDUNILVR    0.005551    0.022730    0.001402  -0.002299 -0.002070  0.015210
# ICICIBANK     0.006162   -0.009710    0.002572   0.001951  0.019261 -0.039700
# INFY         -0.003336   -0.030154   -0.000363   0.003507  0.011421 -0.035851
# TATACONSUM -0.022128   -0.014844 -0.000594
# TATASTEEL   0.010889    0.021152 -0.003063
# TECHM      -0.011579    0.074002 -0.020125
# TITAN       0.012377   -0.016714  0.006394
# ULTRACEMCO -0.016714    0.203932 -0.052581
# WIPRO       0.006394   -0.052581  0.013952
#
# [24 rows x 24 columns]

# %%
risk_free_rate = 0.0358 #initializing risk free rate that will be used in calculating both the ratios (absolute value)
#referred from url: https://www.rbi.org.in/Scripts/BS_NSDPDisplay.aspx?param=4&Id=24292
#In the above url, the 364 (1 year) day treasury bill is 3.58% , when taken absolute value => 0.0358
# (improved)

# %%
df
stocks=df.shape[1]
stocks
# Out:
# 24

# %% [markdown]
# # Sharpe

# %%
global_warr_sortino=[]
global_war_sharpe=[]
sharpe_portfolio_return=[]
sharpe_portfolio_risk=[]
sharpe_portfolio_shratio=[]
sharpe_portfolio_stockWeights=[]

# %%
fitness=0
#for each iteration

weights=(np.array(BALANCE([4.57606371261345,9.67698598407907,2.8816471398668,3.76280675093989,6.10005496604961,1.14708159257701,1.63996379334881,3.36411165704113,2.00796787062891,9.13229658964017,1.37274941345458,2.38654278474067,6.25880838891221,2.14733058728827,9.76228755822564,2.01419193025687,7.83900398874845,7.72870344184099,2.27786673057532,3.33226384976688,1.03163727917332,7.21709695950646,0.606271511043036,1.73626551968245
])))

#calculating annulaised portfolio return
returns_temp = np.sum(returnsh.mean()*weights)*trading_days 

#calculating portfolio varience wrt calculating sharpe ratio
varsh=np.dot(weights.T,np.dot(covmatsh,weights))   

#portfolio risk
volatility_temp = np.sqrt(varsh)      

#Calculating fitness value(ie sharpe ratio)
fitness = ratio(returns_temp,volatility_temp,risk_free_rate)

#Initializing the intial fitness value as the best fitness value(sharpe_pbest)


sharpe_portfolio_return.append(returns_temp)
sharpe_portfolio_risk.append(volatility_temp)
sharpe_portfolio_shratio.append(fitness)
sharpe_portfolio_stockWeights.append(weights)

# %%
sharpe_portfolio = {'Returns' : sharpe_portfolio_return, 'Standard Deviation' : sharpe_portfolio_risk,  'Sharpe Ratio' : sharpe_portfolio_shratio}  

for counter,symbol in enumerate(df.columns):
  sharpe_portfolio[symbol + " Weight"] = [Weight[counter] for Weight in sharpe_portfolio_stockWeights]
sharpe_pc = pd.DataFrame(sharpe_portfolio)
sharpe_optimal=sharpe_pc.iloc[sharpe_pc['Sharpe Ratio'].idxmax()]
sharpe_optimal=pd.DataFrame(sharpe_optimal)
sharpe_optimal.to_csv(str(end)+"Sharpe_MVO_B.csv")

sharpe_pc
# Out:
#     Returns  Standard Deviation  Sharpe Ratio  ASIANPAINT Weight  \
# 0 -2.103956            0.026076    -82.059914           0.045761
#
#    BAJFINANCE Weight  BAJAJFINSV Weight  BRITANNIA Weight  DIVISLAB Weight  \
# 0            0.09677           0.028816          0.037628         0.061001
#
#    GRASIM Weight  HCLTECH Weight  ...  NESTLEIND Weight  POWERGRID Weight  \
# 0       0.011471          0.0164  ...          0.097623          0.020142
#
#    RELIANCE Weight  TCS Weight  TATACONSUM Weight  TATASTEEL Weight  \
# 0          0.07839    0.077287           0.022779          0.033323
#
#    TECHM Weight  TITAN Weight  ULTRACEMCO Weight  WIPRO Weight
# 0      0.010316      0.072171           0.006063      0.017363
#
# [1 rows x 27 columns]

# %%
sharpe_pc.shape
# Out:
# (1, 27)

# %% [markdown]
# # Sortino

# %%
global_warr_sortino=[]
sortino_portfolio_return=[]
sortino_portfolio_risk=[]
sortino_portfolio_soratio=[]
sortino_portfolio_stockWeights=[]

# %%
fitness=0
#for each iteration


#Making sure that the total amount of pheromone equals 1 
weights=np.array(BALANCE([4.57606371261345,9.67698598407907,2.8816471398668,3.76280675093989,6.10005496604961,1.14708159257701,1.63996379334881,3.36411165704113,2.00796787062891,9.13229658964017,1.37274941345458,2.38654278474067,6.25880838891221,2.14733058728827,9.76228755822564,2.01419193025687,7.83900398874845,7.72870344184099,2.27786673057532,3.33226384976688,1.03163727917332,7.21709695950646,0.606271511043036,1.73626551968245
]))

#calculating annulaised portfolio return
returns_temp = np.sum(returnsh.mean()*weights)*trading_days 

#calculating portfolio varience wrt calculating sharpe ratio
varso=np.dot(weights.T,np.dot(covmatso,weights))   

#portfolio risk
volatility_temp = np.sqrt(varso)      

#Calculating fitness value(ie sortino ratio)
fitness = ratio(returns_temp,volatility_temp,risk_free_rate)

#Initializing the intial fitness value as the best fitness value(sortino_pbest)

sortino_portfolio_return.append(returns_temp)
sortino_portfolio_risk.append(volatility_temp)
sortino_portfolio_soratio.append(fitness)
sortino_portfolio_stockWeights.append(weights)

# %%
sortino_portfolio = {'Returns' : sortino_portfolio_return, 'Standard Deviation' : sortino_portfolio_risk,  'Sortino Ratio' : sortino_portfolio_soratio}  

for counter,symbol in enumerate(df.columns):
  sortino_portfolio[symbol + " Weight"] = [Weight[counter] for Weight in sortino_portfolio_stockWeights]
sortino_pc = pd.DataFrame(sortino_portfolio)
sortino_optimal=sortino_pc.iloc[sortino_pc['Sortino Ratio'].idxmax()]
sortino_optimal=pd.DataFrame(sortino_optimal)
sortino_optimal.to_csv(str(end)+"Sortino_MVO_B.csv")
sortino_pc
# Out:
#     Returns  Standard Deviation  Sortino Ratio  ASIANPAINT Weight  \
# 0 -2.103956             0.03948     -54.198448           0.045761
#
#    BAJFINANCE Weight  BAJAJFINSV Weight  BRITANNIA Weight  DIVISLAB Weight  \
# 0            0.09677           0.028816          0.037628         0.061001
#
#    GRASIM Weight  HCLTECH Weight  ...  NESTLEIND Weight  POWERGRID Weight  \
# 0       0.011471          0.0164  ...          0.097623          0.020142
#
#    RELIANCE Weight  TCS Weight  TATACONSUM Weight  TATASTEEL Weight  \
# 0          0.07839    0.077287           0.022779          0.033323
#
#    TECHM Weight  TITAN Weight  ULTRACEMCO Weight  WIPRO Weight
# 0      0.010316      0.072171           0.006063      0.017363
#
# [1 rows x 27 columns]

# %%
#tables in word doc also(final table)
